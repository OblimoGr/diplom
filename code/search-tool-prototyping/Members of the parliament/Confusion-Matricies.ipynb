# %% [markdown]
# # Search Results Members Of Parliament: Confussion Matricies

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Twitter
# ---

# %% [markdown]
# ## Fullnames
# - TP: 107
# - FP: 131
# - TN: 46
# - FN: 16

# %%
result = np.array([[46.,16.],[131., 107.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Fullnames Classified
# - TP: 84
# - FP: 155
# - TN: 57
# - FN: 4

# %%
result = np.array([[57.,155.],[4., 84.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames
# - TP: 159
# - FP: 79
# - TN: 7
# - FN: 55

# %%
result = np.array([[7.,79.],[55., 159.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Classified
# - TP: 121
# - FP: 117
# - TN: 53
# - FN: 9

# %%
result = np.array([[53.,117.],[9., 121.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Latin
# - TP: 119
# - FP: 119
# - TN: 4
# - FN: 58

# %%
result = np.array([[4.,119.],[58., 119.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Latin Classified
# - TP: 102
# - FP: 136
# - TN: 58
# - FN: 4

# %%
result = np.array([[58.,136.],[4., 102.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# # Google

# %% [markdown]
# ## Fullnames
# - TP: 181
# - FP: 57
# - TN: 38
# - FN: 24

# %%
result = np.array([[38.,57.],[24., 181.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Fullnames Classified
# - TP: 140
# - FP: 98
# - TN: 57
# - FN: 5

# %%
result = np.array([[57.,98.],[5., 140.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames
# - TP: 181
# - FP: 57
# - TN: 26
# - FN: 36

# %%
result = np.array([[26.,57.],[36., 181.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Classified
# - TP: 137
# - FP: 101
# - TN: 52
# - FN: 10

# %%
result = np.array([[52.,101.],[10., 137.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Latin
# - TP: 131
# - FP: 107
# - TN: 39
# - FN: 33

# %%
result = np.array([[39.,107.],[33., 131.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]

# %% [markdown]
# ## Surnames Latin Classified
# - TP: 104
# - FP: 134
# - TN: 60
# - FN: 2

# %%
result = np.array([[59.,135.],[2., 104.]])

# %%
target_names = ['Does not have an Account', 'Has an Account']

# %%
#plt.figure(figsize=(10,7))
sns.set(font_scale=1) # for label size
mtrx = sns.heatmap(result.round(), annot=True, annot_kws={"size": 15},
           cmap=plt.cm.Blues,
           xticklabels=target_names, 
            yticklabels=target_names,
            fmt='g') # font size

loc, labels = plt.xticks()
mtrx.set_xticklabels(labels, rotation=45)
mtrx.set_yticklabels(labels, rotation=45)
# Out:
# [Text(0, 0.5, 'Does not have an Account'), Text(0, 1.5, 'Has an Account')]
