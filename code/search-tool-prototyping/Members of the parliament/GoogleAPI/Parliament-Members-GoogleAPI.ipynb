# %% [markdown]
# # Search Tool Members of the Parliament: GoogleAPI

# %% [markdown]
# ----
# Libraries:

# %%
import re
import numpy as np
import pandas as pd
import json 
from batoomer.twitter_nodes.search_engine import GoogleSearchEngine
from googleapiclient.errors import HttpError
from tqdm.notebook import tqdm
import time

# %% [markdown]
# ---
# Load Google Credentials and initialize GoogleSearchEngine

# %%
keys = []
with open('../../../../google_credentials.json', 'r') as f:
    keys = json.load(f)

se = GoogleSearchEngine(google_api_key=keys['api_key'], search_engine_id=keys['twitter_seID'])

# %% [markdown]
# ---
# ## Dataset

# %%
data = pd.read_csv('../../../../datasets/Greek Politicians/search-tool/parliament-members-new.csv')
data.replace(np.nan, '', inplace=True)
data.head(5)
# Out:
#                                        Name (Long)        Surname  \
# 0                    Βιλιάρδος Διονυσίου Βασίλειος      Βιλιάρδος
# 1  Αλεξοπούλου Κωνσταντίνου Αναστασία - Αικατερίνη    Αλεξοπούλου
# 2                        Αθανασίου Ευαγγέλου Μαρία      Αθανασίου
# 3                   Βαγενάς Κωνσταντίνου Δημήτριος        Βαγενάς
# 4            Ασημακοπούλου Δημητρίου Σοφία - Χάιδω  Ασημακοπούλου
#
#                      Name          Party   Twitter Handle
# 0     Βιλιάρδος Βασίλειος  ΕΛΛΗΝΙΚΗ ΛΥΣΗ       ViliardosV
# 1  Αλεξοπούλου Αικατερίνη  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        anaik2020
# 2         Αθανασίου Μαρία  ΕΛΛΗΝΙΚΗ ΛΥΣΗ  MariaAt03902914
# 3       Βαγενάς Δημήτριος  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        B3Vagenas
# 4     Ασημακοπούλου Χάιδω  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        SofAsimak

# %% [markdown]
# ---
# ## Search: Fullname

# %%
queries = list(data['Name'])
results = pd.DataFrame()

for query in tqdm(queries):
    try:
        se.search(query=query)
        result = se.get_results()
        results= results.append(result)
    except HttpError as err:
        if err.resp.status == 429:
            print('Api Limit Hit!')
            time.sleep(60 * 60 * 24)
            se.search(query=query)
            result = se.get_results()
            results= results.append(result)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ac73fde36469> in <module>
#       4 for query in tqdm(queries):
#       5     try:
# ----> 6         se.search(query=query)
#       7         result = se.get_results()
#       8         results= results.append(result)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/batoomer/twitter_nodes/search_engine.py in search(self, query)
#     101     def search(self, query):
#     102         # Call __google_search method to get the results
# --> 103         result = self.__google_search(query=f'{query} twitter', api=self._api, seID=self._seID)
#     104
#     105         # Variable to keep twitter accounts
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/batoomer/twitter_nodes/search_engine.py in __google_search(query, api, seID)
#      97         """
#      98         service = build('customsearch', 'v1', developerKey=api)
# ---> 99         return service.cse().list(q=query, cx=seID).execute()
#     100
#     101     def search(self, query):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     898
#     899         # Handle retries for server-side errors.
# --> 900         resp, content = _retry_request(
#     901             http,
#     902             num_retries,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/googleapiclient/http.py in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     175         try:
#     176             exception = None
# --> 177             resp, content = http.request(uri, method, *args, **kwargs)
#     178         # Retry on SSL errors and socket timeout errors.
#     179         except _ssl_SSLError as ssl_error:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1706                     content = b""
#    1707                 else:
# -> 1708                     (response, content) = self._request(
#    1709                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1710                     )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1422             auth.request(method, request_uri, headers, body)
#    1423
# -> 1424         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1425
#    1426         if auth:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1374                 pass
#    1375             try:
# -> 1376                 response = conn.getresponse()
#    1377             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1378                 # If we get a BadStatusLine on the first try then that means
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
results

# %%
results_df = (results
           .replace(np.nan, '')
           .rename(columns={'Query':'Name'})
           .reset_index()
           .drop('index', axis=1))
results_df = pd.merge(data, results_df, on=results_df.index, how='outer').drop(['key_0', 'Name_y'], axis =1).rename(columns={'Name_x':'Name'})
results_df.head(5)

# %%
results_df.to_csv('Google-Search-Fullnames-Parliament-Members.csv', index=False)

# %% [markdown]
# ---
# ## Search: Surname

# %%
queries = list(data['Surname'])
results = pd.DataFrame()

for query in tqdm(queries):
    try:
        se.search(query=query)
        result = se.get_results()
        results= results.append(result)
    except HttpError as err:
        if err.resp.status == 429:
            print('Api Limit Hit!')
            time.sleep(60 * 60 * 24)
            se.search(query=query)
            result = se.get_results()
            results= results.append(result)

# %%
results

# %%
results_df = (results
           .replace(np.nan, '')
           .rename(columns={'Query':'Surname'})
           .reset_index()
           .drop('index', axis=1))
results_df = pd.merge(data, results_df, on=results_df.index, how='outer').drop(['key_0', 'Surname_y'], axis =1).rename(columns={'Surname_x':'Surname'})
results_df.head(5)

# %%
results_df.to_csv('Google-Search-Surnames-Parliament-Members.csv', index=False)

# %% [markdown]
# ---
# ## Search: Fullname Greeklish

# %%
## https://github.com/gschizas/RomanizePython/blob/master/romanize/__init__.py

def romanize(greek_text):
    """Return the ISO 843:1997 transcription of the input Greek text.
    Any non-Greek characters will be ignored and printed as they were."""

    result = ""
    cursor = 0
    while cursor < len(greek_text):
        letter = greek_text[cursor]
        prev_letter = greek_text[cursor - 1] if cursor > 0 else ""
        next_letter = greek_text[cursor + 1] if cursor < len(greek_text) - 1 else ""
        third_letter = greek_text[cursor + 2] if cursor < len(greek_text) - 2 else ""

        is_upper = (letter.upper() == letter)
        is_upper_next = (next_letter.upper() == next_letter)
        letter = letter.lower()
        prev_letter = prev_letter.lower()
        next_letter = next_letter.lower()
        third_letter = third_letter.lower()

        simple_translation_greek = u'άβδέζήιίϊΐκλνξόπρσςτυύϋΰφωώ'
        simple_translation_latin = u'avdeziiiiiklnxoprsstyyyyfoo'

        digraph_translation_greek = u'θχψ'
        digraph_translation_latin = u'thchps'

        digraph_ypsilon_greek = u'αεη'
        digraph_ypsilon_latin = u'aei'
        digraph_ypsilon_beta = u'βγδζλμνραάεέηήιίϊΐοόυύϋΰωώ'
        digraph_ypsilon_phi = u'θκξπστφχψ'

        if letter in simple_translation_greek:
            new_letter = simple_translation_latin[simple_translation_greek.index(letter)]
        elif letter in digraph_translation_greek:
            diphthong_index = digraph_translation_greek.index(letter)
            new_letter = digraph_translation_latin[diphthong_index * 2:diphthong_index * 2 + 2]
        elif letter in digraph_ypsilon_greek:
            new_letter = digraph_ypsilon_latin[digraph_ypsilon_greek.index(letter)]
            if next_letter in [u'υ', u'ύ']:
                if third_letter in digraph_ypsilon_beta:
                    new_letter += u'v'
                    cursor += 1
                elif third_letter in digraph_ypsilon_phi:
                    new_letter += u'f'
                    cursor += 1
        elif letter == u'γ':
            if next_letter == u'γ':
                new_letter = u'ng'
                cursor += 1
            elif next_letter == u'ξ':
                new_letter = u'nx'
                cursor += 1
            elif next_letter in u'χ':
                new_letter = u'nch'
                cursor += 1
            else:
                new_letter = u'g'
        elif letter == u'μ':
            if next_letter == u'π':
                if prev_letter.strip() == "" or third_letter.strip() == "":
                    new_letter = u'b'
                    cursor += 1
                else:
                    new_letter = u'mp'
                    cursor += 1
            else:
                new_letter = u'm'
        elif letter == u'ο':
            new_letter = u'o'
            if next_letter in [u'υ', u'ύ']:
                new_letter += u'u'
                cursor += 1
        else:
            new_letter = letter
        if is_upper:
            new_letter = new_letter[0].upper() + (new_letter[1:].upper() if is_upper_next else new_letter[1:].lower())
        result += new_letter
        cursor += 1
    return result

# %%
queries = list(data['Name'])
results = pd.DataFrame()

for query in tqdm(queries):
    try:
        se.search(query=romanize(query))
        result = se.get_results()
        results= results.append(result)
    except HttpError as err:
        if err.resp.status == 429:
            print('Api Limit Hit!')
            time.sleep(60 * 60 * 24)
            se.search(query=query)
            result = se.get_results()
            results= results.append(result)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Api Limit Hit!
# Api Limit Hit!
# Api Limit Hit!

# %%
results
# Out:
#                      Query          Result 1            Result 2  \
# 0      Viliardos Vasileios       @ViliardosV         @ViliardosV
# 0   Αλεξοπούλου Αικατερίνη        @anaik2020       @kkroonenberg
# 0         Athanasiou Maria  @mariaathanasiou  @athanasiou_marios
# 0        Vagenas Dimitrios  @DimitriosVagen1                 NaN
# 0     Asimakopoulou Chaido   @eri__valentina         @village_gr
# ..                     ...               ...                 ...
# 0       Sarakiotis Ioannis      @JSarakiotis        @jsarakiotis
# 0               Perka Peti        @PetiPerka          @PetiPerka
# 0           Malama Kyriaki    @KiriakiMalama                 NaN
# 0           Polakis Pavlos    @PavlosPolakis         @pavpol2222
# 0      Michailidis Andreas     @MichailidisA                 NaN
#
#             Result 3   Result 4             Result 5 Result 6 Result 7  \
# 0                NaN        NaN                  NaN      NaN      NaN
# 0           @djnikas        NaN                  NaN      NaN      NaN
# 0   @45b1584e2f7d481  @athinadi  @hotelthesantamaria      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
# ..               ...        ...                  ...      ...      ...
# 0                NaN        NaN                  NaN      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
# 0                NaN        NaN                  NaN      NaN      NaN
#
#    Result 8
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN
# ..      ...
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN
#
# [300 rows x 9 columns]

# %%
results_df = (results
           .replace(np.nan, '')
           .rename(columns={'Query':'Name'})
           .reset_index()
           .drop('index', axis=1))
results_df = pd.merge(data, results_df, on=results_df.index, how='outer').drop(['key_0', 'Name_y'], axis =1).rename(columns={'Name_x':'Name'})
results_df.head(5)
# Out:
#                                        Name (Long)        Surname  \
# 0                    Βιλιάρδος Διονυσίου Βασίλειος      Βιλιάρδος
# 1  Αλεξοπούλου Κωνσταντίνου Αναστασία - Αικατερίνη    Αλεξοπούλου
# 2                        Αθανασίου Ευαγγέλου Μαρία      Αθανασίου
# 3                   Βαγενάς Κωνσταντίνου Δημήτριος        Βαγενάς
# 4            Ασημακοπούλου Δημητρίου Σοφία - Χάιδω  Ασημακοπούλου
#
#                      Name          Party   Twitter Handle          Result 1  \
# 0     Βιλιάρδος Βασίλειος  ΕΛΛΗΝΙΚΗ ΛΥΣΗ       ViliardosV       @ViliardosV
# 1  Αλεξοπούλου Αικατερίνη  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        anaik2020        @anaik2020
# 2         Αθανασίου Μαρία  ΕΛΛΗΝΙΚΗ ΛΥΣΗ  MariaAt03902914  @mariaathanasiou
# 3       Βαγενάς Δημήτριος  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        B3Vagenas  @DimitriosVagen1
# 4     Ασημακοπούλου Χάιδω  ΕΛΛΗΝΙΚΗ ΛΥΣΗ        SofAsimak   @eri__valentina
#
#              Result 2          Result 3   Result 4             Result 5  \
# 0         @ViliardosV
# 1       @kkroonenberg          @djnikas
# 2  @athanasiou_marios  @45b1584e2f7d481  @athinadi  @hotelthesantamaria
# 3
# 4         @village_gr
#
#   Result 6 Result 7 Result 8
# 0
# 1
# 2
# 3
# 4

# %%
results_df.to_csv('Google-Search-FullnamesLatin-Parliament-Members.csv', index=False)
