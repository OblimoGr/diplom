# %% [markdown]
# # Hotels: Search Facebook Accounts

# %%
import re
import numpy as np
import pandas as pd
import json 
from batoomer.twitter_nodes.search_engine import GoogleSearchEngine
from googleapiclient.errors import HttpError
from tqdm.notebook import tqdm
import time

# %% [markdown]
# ---
# Load Google Credentials and initialize GoogleSearchEngine

# %%
keys = []
with open('../../../../google_credentials.json', 'r') as f:
    keys = json.load(f)

se = GoogleSearchEngine(google_api_key=keys['api_key'], search_engine_id=keys['twitter_seID'])

# %%
data = pd.read_csv('../../../../datasets/Hotels/search-tool/greek-hotels-2018-search.csv', delimiter=';')
data.replace(np.nan, '', inplace=True)
data.head(5)
# Out:
#          Hotel City              Hotelname Twitter Handle  \
# 0          Acharavi          Hotel Matoula
# 1          Acharavi   Hotel Acharavi Beach
# 2  Adelianos Kampos    Hotel Kathrin Beach
# 3           Afandou           Aelia Resort
# 4      Agia Pelagia  Hotel Alexander House
#
#                             Website  \
# 0
# 1    https://www.acharavibeach.com/
# 2         https://kathrinbeach.com/
# 3
# 4  http://www.alexanderhouse.gr/en/
#
#                                      Facebook Handle
# 0
# 1  https://www.facebook.com/AcharaviBeachHotelCorfu/
# 2  https://www.facebook.com/Kathrin-Beach-Hotel-1...
# 3
# 4       https://www.facebook.com/alexanderhousehotel

# %% [markdown]
# ## Hotelname

# %%
queries = list(data['Hotelname'])
results = pd.DataFrame()

for query in tqdm(queries):
    try:
        se.search(query=query, platform='facebook')
        result = se.get_results()
        results= results.append(result)
    except HttpError as err:
        if err.resp.status == 429:
            print('Api Limit Hit!')
            time.sleep(60 * 60 * 24)
            se.search(query=query, platform='facebook')
            result = se.get_results()
            results= results.append(result)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
results = (results
           .replace(np.nan, '')
           .rename(columns={'Query':'poi'})
           .reset_index()
           .drop('index', axis=1))
results.head(5)
# Out:
#                      poi                                           Result 1  \
# 0          Hotel Matoula        https://www.facebook.com/matoulabeachhotel/
# 1   Hotel Acharavi Beach  https://www.facebook.com/AcharaviBeachHotelCorfu/
# 2    Hotel Kathrin Beach              https://www.facebook.com/katrinhotel/
# 3           Aelia Resort     https://www.facebook.com/aeliawellnessretreat/
# 4  Hotel Alexander House                    https://www.facebook.com/AHSpa/
#
#                                             Result 2  \
# 0           https://www.facebook.com/pansionmatoula/
# 1  https://www.facebook.com/pages/category/Hotel/...
# 2     https://www.facebook.com/beautifulmiamirealty/
# 3        https://www.facebook.com/AeliaResortRhodes/
# 4          https://www.facebook.com/AlexanderHotels/
#
#                                             Result 3  \
# 0  https://www.facebook.com/Storgi-Matoula-Gianno...
# 1        https://www.facebook.com/AcharaviAphrodite/
# 2
# 3  https://www.facebook.com/pages/category/Hotel/...
# 4      https://www.facebook.com/alexanderhousehotel/
#
#                                             Result 4  \
# 0             https://www.facebook.com/HotelDelfini/
# 1            https://www.facebook.com/vlachosaparts/
# 2
# 3             https://www.facebook.com/aeliamykonos/
# 4  https://www.facebook.com/AlexanderHouseApartme...
#
#                                             Result 5  \
# 0  https://www.facebook.com/Eurostar-Rent-A-Car-8...
# 1
# 2
# 3  https://www.facebook.com/Aelia-Sivota-Apartmen...
# 4        https://www.facebook.com/alexanderoakridge/
#
#                                      Result 6  \
# 0  https://www.facebook.com/EvoraSuitesCreta/
# 1
# 2
# 3
# 4
#
#                                             Result 7  \
# 0  https://www.facebook.com/pages/category/Local-...
# 1
# 2
# 3
# 4
#
#                                       Result 8 Result 9 Result 10
# 0  https://www.facebook.com/byannakouloumvaki/
# 1
# 2
# 3
# 4

# %%
results.to_csv('Google-Search-hotelname-facebook.csv', index=False)

# %% [markdown]
# ## Hotelname + Location

# %%
queries = list(data['Hotelname']+' ' +data['Hotel City'])
results = pd.DataFrame()

for query in tqdm(queries):
    try:
        se.search(query=query, platform='facebook')
        result = se.get_results()
        results= results.append(result)
    except HttpError as err:
        if err.resp.status == 429:
            print('Api Limit Hit!')
            time.sleep(60 * 60 * 24)
            se.search(query=query, platform='facebook')
            result = se.get_results()
            results= results.append(result)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
results = (results
           .replace(np.nan, '')
           .rename(columns={'Query':'poi'})
           .reset_index()
           .drop('index', axis=1))
results.head(5)
# Out:
#                                     poi  \
# 0                Hotel Matoula Acharavi
# 1         Hotel Acharavi Beach Acharavi
# 2  Hotel Kathrin Beach Adelianos Kampos
# 3                  Aelia Resort Afandou
# 4    Hotel Alexander House Agia Pelagia
#
#                                             Result 1  \
# 0     https://www.facebook.com/philoxeniaguesthouse/
# 1  https://www.facebook.com/AcharaviBeachHotelCorfu/
# 2        https://www.facebook.com/StellaKatrinHotel/
# 3        https://www.facebook.com/AeliaResortRhodes/
# 4      https://www.facebook.com/alexanderhousehotel/
#
#                                         Result 2  \
# 0         https://www.facebook.com/hotelphyllis/
# 1    https://www.facebook.com/AcharaviAphrodite/
# 2             https://www.facebook.com/alltours/
# 3  https://www.facebook.com/Olivetreefarmrhodes/
# 4      https://www.facebook.com/pelagiabayhotel/
#
#                                             Result 3  \
# 0           https://www.facebook.com/thassossunrise/
# 1       https://www.facebook.com/acharavibeachvilla/
# 2
# 3    https://www.facebook.com/TheodoridisApartments/
# 4  https://www.facebook.com/derpartreisebuerogoslar/
#
#                                   Result 4  \
# 0
# 1  https://www.facebook.com/vlachosaparts/
# 2
# 3  https://www.facebook.com/solotour.zlin/
# 4   https://www.facebook.com/taxiheraklio/
#
#                                      Result 5  \
# 0
# 1
# 2
# 3  https://www.facebook.com/seaandsunvillage/
# 4         https://www.facebook.com/statusMLB/
#
#                               Result 6  \
# 0
# 1
# 2
# 3  https://www.facebook.com/VillaPico/
# 4
#
#                                  Result 7  \
# 0
# 1
# 2
# 3  https://www.facebook.com/elitozsuites/
# 4
#
#                                  Result 8 Result 9 Result 10
# 0
# 1
# 2
# 3  https://www.facebook.com/obatimehotel/
# 4

# %%
results.to_csv('Google-Search-hotelname-location-facebook.csv', index=False)
